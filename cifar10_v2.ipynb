# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

MODELO = 2

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))
#model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation='relu'))

model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 32)                65568
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                330
# =================================================================
# Total params: 76,042
# Trainable params: 76,042
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

fig, ax = plt.subplots(figsize=(10,10))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]],fontsize = 14)

plt.subplots_adjust(hspace = 0.2)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
fig.savefig("ejemplos.png")

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, epochs=20, 
                    use_multiprocessing=False, batch_size= 512, 
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 2s 23ms/step - loss: 2.1030 - accuracy: 0.2332 - val_loss: 1.6674 - val_accuracy: 0.4086
# Epoch 2/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.6001 - accuracy: 0.4332 - val_loss: 1.5382 - val_accuracy: 0.4599
# Epoch 3/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.4579 - accuracy: 0.4837 - val_loss: 1.4350 - val_accuracy: 0.4949
# Epoch 4/50
# 79/79 [==============================] - 2s 19ms/step - loss: 1.3654 - accuracy: 0.5158 - val_loss: 1.3526 - val_accuracy: 0.5260
# Epoch 5/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.3164 - accuracy: 0.5385 - val_loss: 1.2968 - val_accuracy: 0.5460
# Epoch 6/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.2553 - accuracy: 0.5602 - val_loss: 1.2935 - val_accuracy: 0.5531
# Epoch 7/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.2128 - accuracy: 0.5771 - val_loss: 1.2107 - val_accuracy: 0.5829
# Epoch 8/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.1629 - accuracy: 0.5908 - val_loss: 1.2315 - val_accuracy: 0.5710
# Epoch 9/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.1435 - accuracy: 0.5998 - val_loss: 1.1663 - val_accuracy: 0.6002
# Epoch 10/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.1039 - accuracy: 0.6132 - val_loss: 1.1654 - val_accuracy: 0.5975
# Epoch 11/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.0941 - accuracy: 0.6182 - val_loss: 1.1523 - val_accuracy: 0.5994
# Epoch 12/50
# 79/79 [==============================] - 2s 19ms/step - loss: 1.0705 - accuracy: 0.6258 - val_loss: 1.1324 - val_accuracy: 0.6046
# Epoch 13/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.0368 - accuracy: 0.6414 - val_loss: 1.1095 - val_accuracy: 0.6142
# Epoch 14/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.0161 - accuracy: 0.6480 - val_loss: 1.0892 - val_accuracy: 0.6232
# Epoch 15/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.0003 - accuracy: 0.6512 - val_loss: 1.0793 - val_accuracy: 0.6230
# Epoch 16/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.9915 - accuracy: 0.6554 - val_loss: 1.0844 - val_accuracy: 0.6288
# Epoch 17/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.9909 - accuracy: 0.6603 - val_loss: 1.0618 - val_accuracy: 0.6344
# Epoch 18/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.9695 - accuracy: 0.6650 - val_loss: 1.0508 - val_accuracy: 0.6406
# Epoch 19/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.9479 - accuracy: 0.6753 - val_loss: 1.0608 - val_accuracy: 0.6335
# Epoch 20/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.9533 - accuracy: 0.6669 - val_loss: 1.0263 - val_accuracy: 0.6446
# Epoch 21/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.9206 - accuracy: 0.6827 - val_loss: 1.0350 - val_accuracy: 0.6463
# Epoch 22/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.9044 - accuracy: 0.6884 - val_loss: 1.0245 - val_accuracy: 0.6458
# Epoch 23/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8918 - accuracy: 0.6932 - val_loss: 1.0128 - val_accuracy: 0.6514
# Epoch 24/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8896 - accuracy: 0.6934 - val_loss: 1.0094 - val_accuracy: 0.6527
# Epoch 25/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8875 - accuracy: 0.6949 - val_loss: 1.0425 - val_accuracy: 0.6427
# Epoch 26/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8737 - accuracy: 0.6972 - val_loss: 0.9955 - val_accuracy: 0.6606
# Epoch 27/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8602 - accuracy: 0.7043 - val_loss: 0.9809 - val_accuracy: 0.6597
# Epoch 28/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8464 - accuracy: 0.7097 - val_loss: 0.9779 - val_accuracy: 0.6629
# Epoch 29/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8411 - accuracy: 0.7132 - val_loss: 0.9919 - val_accuracy: 0.6558
# Epoch 30/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8433 - accuracy: 0.7096 - val_loss: 0.9675 - val_accuracy: 0.6683
# Epoch 31/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8228 - accuracy: 0.7165 - val_loss: 1.0321 - val_accuracy: 0.6513
# Epoch 32/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8365 - accuracy: 0.7109 - val_loss: 1.0176 - val_accuracy: 0.6459
# Epoch 33/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8174 - accuracy: 0.7144 - val_loss: 0.9667 - val_accuracy: 0.6647
# Epoch 34/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7977 - accuracy: 0.7245 - val_loss: 1.0157 - val_accuracy: 0.6479
# Epoch 35/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8022 - accuracy: 0.7253 - val_loss: 1.0116 - val_accuracy: 0.6521
# Epoch 36/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7955 - accuracy: 0.7279 - val_loss: 0.9548 - val_accuracy: 0.6685
# Epoch 37/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7719 - accuracy: 0.7340 - val_loss: 0.9998 - val_accuracy: 0.6590
# Epoch 38/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.7835 - accuracy: 0.7322 - val_loss: 0.9875 - val_accuracy: 0.6651
# Epoch 39/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.7535 - accuracy: 0.7422 - val_loss: 1.0463 - val_accuracy: 0.6425
# Epoch 40/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7787 - accuracy: 0.7326 - val_loss: 0.9892 - val_accuracy: 0.6612
# Epoch 41/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7554 - accuracy: 0.7424 - val_loss: 0.9646 - val_accuracy: 0.6696
# Epoch 42/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.7545 - accuracy: 0.7416 - val_loss: 0.9926 - val_accuracy: 0.6636
# Epoch 43/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7517 - accuracy: 0.7412 - val_loss: 0.9758 - val_accuracy: 0.6692
# Epoch 44/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7346 - accuracy: 0.7449 - val_loss: 0.9702 - val_accuracy: 0.6725
# Epoch 45/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7283 - accuracy: 0.7526 - val_loss: 1.0099 - val_accuracy: 0.6594
# Epoch 46/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7300 - accuracy: 0.7507 - val_loss: 1.0274 - val_accuracy: 0.6578
# Epoch 47/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7342 - accuracy: 0.7460 - val_loss: 0.9480 - val_accuracy: 0.6816
# Epoch 48/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.7098 - accuracy: 0.7596 - val_loss: 0.9959 - val_accuracy: 0.6630
# Epoch 49/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.7147 - accuracy: 0.7528 - val_loss: 0.9865 - val_accuracy: 0.6694
# Epoch 50/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7068 - accuracy: 0.7568 - val_loss: 0.9535 - val_accuracy: 0.6773

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:01:16.721966

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 68.030

# %%
fig, ax = plt.subplots(2,1,figsize=(10,10))
ax[0].set_title('Cross Entropy Loss', fontsize = 20)
ax[0].plot(history.history['loss'], color='blue', label='Train')
ax[0].plot(history.history['val_loss'], color='orange', label='Validation')
ax[0].set_ylabel('Cross Entropy Loss', fontsize = 16)
ax[0].legend(fontsize = 16)

ax[1].set_title('Classification Accuracy', fontsize = 20)
ax[1].plot(history.history['accuracy'], color='blue', label='Train')
ax[1].plot(history.history['val_accuracy'], color='orange', label='Validation')
ax[1].set_ylabel('Classification Accuracy', fontsize = 16)
ax[1].set_xlabel('Epochs', fontsize = 16)
ax[1].legend(fontsize = 16)

plt.show()

# %%
fig.savefig("modelo_"+str(MODELO)+".png")

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
