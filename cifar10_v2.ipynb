# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

MODELO = 3

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation='relu'))

model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_40 (Dense)             (None, 32)                65568
# _________________________________________________________________
# dense_41 (Dense)             (None, 10)                330
# =================================================================
# Total params: 76,042
# Trainable params: 76,042
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

fig, ax = plt.subplots(figsize=(10,10))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]],fontsize = 14)

plt.subplots_adjust(hspace = 0.2)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
fig.savefig("ejemplos.png")

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, epochs=50, 
                    use_multiprocessing=False, batch_size= 512, 
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 2s 23ms/step - loss: 2.1517 - accuracy: 0.2118 - val_loss: 1.7325 - val_accuracy: 0.3771
# Epoch 2/50
# 79/79 [==============================] - 2s 19ms/step - loss: 1.6624 - accuracy: 0.4090 - val_loss: 1.5231 - val_accuracy: 0.4588
# Epoch 3/50
# 79/79 [==============================] - 2s 20ms/step - loss: 1.4723 - accuracy: 0.4772 - val_loss: 1.4315 - val_accuracy: 0.4930
# Epoch 4/50
# 79/79 [==============================] - 2s 19ms/step - loss: 1.3788 - accuracy: 0.5159 - val_loss: 1.3757 - val_accuracy: 0.5065
# Epoch 5/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.3085 - accuracy: 0.5377 - val_loss: 1.3691 - val_accuracy: 0.5209
# Epoch 6/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.2799 - accuracy: 0.5476 - val_loss: 1.2760 - val_accuracy: 0.5537
# Epoch 7/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.2182 - accuracy: 0.5706 - val_loss: 1.2611 - val_accuracy: 0.5549
# Epoch 8/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.1940 - accuracy: 0.5811 - val_loss: 1.2057 - val_accuracy: 0.5834
# Epoch 9/50
# 79/79 [==============================] - 2s 19ms/step - loss: 1.1685 - accuracy: 0.5930 - val_loss: 1.2367 - val_accuracy: 0.5678
# Epoch 10/50
# 79/79 [==============================] - 2s 19ms/step - loss: 1.1436 - accuracy: 0.6012 - val_loss: 1.1960 - val_accuracy: 0.5779
# Epoch 11/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.1289 - accuracy: 0.6053 - val_loss: 1.1586 - val_accuracy: 0.5967
# Epoch 12/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.0859 - accuracy: 0.6234 - val_loss: 1.1704 - val_accuracy: 0.5924
# Epoch 13/50
# 79/79 [==============================] - 2s 19ms/step - loss: 1.0653 - accuracy: 0.6347 - val_loss: 1.1225 - val_accuracy: 0.6109
# Epoch 14/50
# 79/79 [==============================] - 1s 19ms/step - loss: 1.0312 - accuracy: 0.6435 - val_loss: 1.1016 - val_accuracy: 0.6202
# Epoch 15/50
# 79/79 [==============================] - 2s 19ms/step - loss: 1.0407 - accuracy: 0.6389 - val_loss: 1.0836 - val_accuracy: 0.6291
# Epoch 16/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.9988 - accuracy: 0.6538 - val_loss: 1.0944 - val_accuracy: 0.6189
# Epoch 17/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.9976 - accuracy: 0.6525 - val_loss: 1.1215 - val_accuracy: 0.6081
# Epoch 18/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.9905 - accuracy: 0.6566 - val_loss: 1.0555 - val_accuracy: 0.6395
# Epoch 19/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.9759 - accuracy: 0.6621 - val_loss: 1.0617 - val_accuracy: 0.6376
# Epoch 20/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.9442 - accuracy: 0.6756 - val_loss: 1.0583 - val_accuracy: 0.6351
# Epoch 21/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.9402 - accuracy: 0.6757 - val_loss: 1.0591 - val_accuracy: 0.6339
# Epoch 22/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.9343 - accuracy: 0.6802 - val_loss: 1.0762 - val_accuracy: 0.6291
# Epoch 23/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.9295 - accuracy: 0.6793 - val_loss: 1.0857 - val_accuracy: 0.6289
# Epoch 24/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.9168 - accuracy: 0.6859 - val_loss: 1.0142 - val_accuracy: 0.6530
# Epoch 25/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8873 - accuracy: 0.6952 - val_loss: 1.0704 - val_accuracy: 0.6263
# Epoch 26/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8976 - accuracy: 0.6891 - val_loss: 1.0424 - val_accuracy: 0.6467
# Epoch 27/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.8788 - accuracy: 0.6966 - val_loss: 1.0068 - val_accuracy: 0.6545
# Epoch 28/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8688 - accuracy: 0.7031 - val_loss: 1.0430 - val_accuracy: 0.6413
# Epoch 29/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8548 - accuracy: 0.7052 - val_loss: 1.0315 - val_accuracy: 0.6426
# Epoch 30/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8488 - accuracy: 0.7081 - val_loss: 0.9923 - val_accuracy: 0.6637
# Epoch 31/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8371 - accuracy: 0.7127 - val_loss: 0.9838 - val_accuracy: 0.6648
# Epoch 32/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8240 - accuracy: 0.7172 - val_loss: 0.9858 - val_accuracy: 0.6601
# Epoch 33/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8278 - accuracy: 0.7120 - val_loss: 0.9967 - val_accuracy: 0.6591
# Epoch 34/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.8124 - accuracy: 0.7172 - val_loss: 0.9702 - val_accuracy: 0.6687
# Epoch 35/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8154 - accuracy: 0.7233 - val_loss: 0.9803 - val_accuracy: 0.6657
# Epoch 36/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.8078 - accuracy: 0.7243 - val_loss: 0.9975 - val_accuracy: 0.6600
# Epoch 37/50
# 79/79 [==============================] - 1s 19ms/step - loss: 0.7875 - accuracy: 0.7322 - val_loss: 0.9486 - val_accuracy: 0.6765
# Epoch 38/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7804 - accuracy: 0.7324 - val_loss: 0.9792 - val_accuracy: 0.6662
# Epoch 39/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7856 - accuracy: 0.7312 - val_loss: 0.9841 - val_accuracy: 0.6670
# Epoch 40/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7847 - accuracy: 0.7308 - val_loss: 0.9566 - val_accuracy: 0.6742
# Epoch 41/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7674 - accuracy: 0.7350 - val_loss: 0.9652 - val_accuracy: 0.6732
# Epoch 42/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7527 - accuracy: 0.7421 - val_loss: 0.9526 - val_accuracy: 0.6764
# Epoch 43/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7419 - accuracy: 0.7478 - val_loss: 0.9983 - val_accuracy: 0.6635
# Epoch 44/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7680 - accuracy: 0.7328 - val_loss: 0.9463 - val_accuracy: 0.6802
# Epoch 45/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7282 - accuracy: 0.7519 - val_loss: 0.9839 - val_accuracy: 0.6677
# Epoch 46/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7414 - accuracy: 0.7448 - val_loss: 0.9978 - val_accuracy: 0.6644
# Epoch 47/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7414 - accuracy: 0.7449 - val_loss: 0.9505 - val_accuracy: 0.6791
# Epoch 48/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7244 - accuracy: 0.7525 - val_loss: 0.9516 - val_accuracy: 0.6817
# Epoch 49/50
# 79/79 [==============================] - 2s 20ms/step - loss: 0.7243 - accuracy: 0.7498 - val_loss: 0.9490 - val_accuracy: 0.6793
# Epoch 50/50
# 79/79 [==============================] - 2s 19ms/step - loss: 0.7111 - accuracy: 0.7571 - val_loss: 1.0197 - val_accuracy: 0.6608

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:01:17.171623

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 66.280

# %%
fig, ax = plt.subplots(2,1,figsize=(10,10))
ax[0].set_title('Cross Entropy Loss', fontsize = 20)
ax[0].plot(history.history['loss'], color='blue', label='Train')
ax[0].plot(history.history['val_loss'], color='orange', label='Validation')
ax[0].set_ylabel('Cross Entropy Loss', fontsize = 16)
ax[0].legend(fontsize = 16)

ax[1].set_title('Classification Accuracy', fontsize = 20)
ax[1].plot(history.history['accuracy'], color='blue', label='Train')
ax[1].plot(history.history['val_accuracy'], color='orange', label='Validation')
ax[1].set_ylabel('Classification Accuracy', fontsize = 16)
ax[1].set_xlabel('Epochs', fontsize = 16)
ax[1].legend(fontsize = 16)

plt.show()

# %%
fig.savefig("modelo_"+str(MODELO)+".png")

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
