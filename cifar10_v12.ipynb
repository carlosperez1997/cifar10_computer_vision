# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model

MODELO = 11

ANCHO_IMAGEN, ALTURA_IMAGEN, CANALES_IMAGENES = 32, 32, 3

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
    kernel_initializer='he_uniform', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.6))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', 
    kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Flatten())

model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.4))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.4))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 5,555,338
# Trainable params: 5,551,882
# Non-trainable params: 3,456
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
from tensorflow.keras.optimizers import Adam
from keras.optimizers import SGD

new_adam = Adam(learning_rate=2e-5)

opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

#x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %%
y_train_rshape = y_train.ravel()
y_val_rshape = y_val.ravel()
y_test_rshape = y_test.ravel()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train_rshape)
y_train_encoded = le.transform(y_train_rshape)
y_val_encoded = le.transform(y_val_rshape)
y_test_encoded = le.transform(y_test_rshape)

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
#x_train_features_vgg = llevar_imagenes_cuellobotella(vgg_model, x_train)
#x_val_features_vgg = llevar_imagenes_cuellobotella(vgg_model, x_val)
#x_test_features_vgg = llevar_imagenes_cuellobotella(vgg_model, x_test)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.1,
    shear_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.15,
    height_shift_range=0.15,
    )

train_generator = train_datagen.flow(
    x_train, 
    y_train_encoded, 
    batch_size=400
)

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=100
)

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=100
)

# %%
sample = 451
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train_encoded[sample:sample+1],
    batch_size=20
)

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
  plt.subplot(5,3,i+1)
  for X, y in example_generator:
    image = X[0]
    plt.imshow(image)
    plt.title(y[0])
    break

plt.tight_layout()
plt.savefig('data_aug.png')
plt.show()

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback = EarlyStopping(monitor='val_loss', patience=3)

# %%
t = time.perf_counter()

# %%
acc = 0

# %%
callback2 = EarlyStopping(monitor='val_loss', patience=2)

# %%
acc_max = 0
acc_worth = 0.905
num_epochs = 500
epochs = 0

while epochs < num_epochs:
  # history = 
  model.fit(train_generator, steps_per_epoch = 100, 
                      validation_steps=100, use_multiprocessing=False,
                      epochs=1, validation_data=validation_generator,
                      callbacks=[callback])
  
  _, acc = model.evaluate(test_generator, verbose=0)

  if acc > acc_max:
    acc_max = acc
    model.save('model.h5')
    print('> %.3f' % (acc * 100.0)) 

  if acc > acc_worth:
    detail_model = model
    opt = SGD(lr=0.0004)
    detail_model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])  

    intentos = 50
    i = 0
    while i < intentos:
      detail_model.fit(train_generator, steps_per_epoch = 100, 
                          validation_steps=100, use_multiprocessing=False,
                          epochs=1, validation_data=validation_generator,
                          callbacks=[callback2])
      
      _, acc = model.evaluate(test_generator, verbose=0)

      if acc > acc_max:
        acc_max = acc
        model = detail_model
        model.save('model_prime.h5')
        print('> %.3f' % (acc * 100.0)) 
      
      i += 1

    epochs += 1
# Out:
# 100/100 [==============================] - 60s 245ms/step - loss: 2.5283 - accuracy: 0.1238 - val_loss: 2.2393 - val_accuracy: 0.1506
# > 14.840
# 100/100 [==============================] - 24s 243ms/step - loss: 1.8751 - accuracy: 0.2648 - val_loss: 2.0896 - val_accuracy: 0.1965
# > 20.240
# 100/100 [==============================] - 24s 244ms/step - loss: 1.6902 - accuracy: 0.3573 - val_loss: 2.0122 - val_accuracy: 0.2739
# > 27.830
# 100/100 [==============================] - 24s 238ms/step - loss: 1.5517 - accuracy: 0.4197 - val_loss: 2.1884 - val_accuracy: 0.3189
# > 32.040
# 100/100 [==============================] - 24s 240ms/step - loss: 1.4299 - accuracy: 0.4833 - val_loss: 1.9142 - val_accuracy: 0.3697
# > 35.920
# 100/100 [==============================] - 24s 239ms/step - loss: 1.3391 - accuracy: 0.5301 - val_loss: 1.5910 - val_accuracy: 0.4578
# > 45.680
# 100/100 [==============================] - 24s 240ms/step - loss: 1.2386 - accuracy: 0.5709 - val_loss: 1.4375 - val_accuracy: 0.5044
# > 49.300
# 100/100 [==============================] - 24s 237ms/step - loss: 1.1649 - accuracy: 0.6007 - val_loss: 1.2907 - val_accuracy: 0.5616
# > 56.090
# 100/100 [==============================] - 24s 238ms/step - loss: 1.1054 - accuracy: 0.6264 - val_loss: 1.0771 - val_accuracy: 0.6220
# > 61.370
# 100/100 [==============================] - 24s 239ms/step - loss: 1.0519 - accuracy: 0.6430 - val_loss: 1.0357 - val_accuracy: 0.6374
# > 63.280
# 100/100 [==============================] - 24s 239ms/step - loss: 0.9947 - accuracy: 0.6662 - val_loss: 1.2100 - val_accuracy: 0.5965
# 100/100 [==============================] - 24s 242ms/step - loss: 0.9423 - accuracy: 0.6873 - val_loss: 0.8802 - val_accuracy: 0.6953
# > 68.310
# 100/100 [==============================] - 24s 237ms/step - loss: 0.9224 - accuracy: 0.6974 - val_loss: 0.7922 - val_accuracy: 0.7308
# > 72.070
# 100/100 [==============================] - 24s 239ms/step - loss: 0.8736 - accuracy: 0.7138 - val_loss: 0.8855 - val_accuracy: 0.6925
# 100/100 [==============================] - 24s 237ms/step - loss: 0.8350 - accuracy: 0.7284 - val_loss: 1.0219 - val_accuracy: 0.6521
# 100/100 [==============================] - 24s 238ms/step - loss: 0.8081 - accuracy: 0.7375 - val_loss: 0.8934 - val_accuracy: 0.6988
# 100/100 [==============================] - 24s 236ms/step - loss: 0.7734 - accuracy: 0.7499 - val_loss: 0.7888 - val_accuracy: 0.7357
# 100/100 [==============================] - 23s 234ms/step - loss: 0.7460 - accuracy: 0.7586 - val_loss: 0.9967 - val_accuracy: 0.6751
# 100/100 [==============================] - 24s 236ms/step - loss: 0.7210 - accuracy: 0.7681 - val_loss: 0.7473 - val_accuracy: 0.7521
# > 73.820
# 100/100 [==============================] - 24s 236ms/step - loss: 0.6987 - accuracy: 0.7772 - val_loss: 0.7083 - val_accuracy: 0.7614
# > 74.870
# 100/100 [==============================] - 24s 238ms/step - loss: 0.6778 - accuracy: 0.7835 - val_loss: 0.7346 - val_accuracy: 0.7493
# 100/100 [==============================] - 24s 237ms/step - loss: 0.6626 - accuracy: 0.7898 - val_loss: 0.7984 - val_accuracy: 0.7411
# 100/100 [==============================] - 24s 236ms/step - loss: 0.6437 - accuracy: 0.7928 - val_loss: 0.7311 - val_accuracy: 0.7530
# 100/100 [==============================] - 23s 234ms/step - loss: 0.6227 - accuracy: 0.8015 - val_loss: 0.6631 - val_accuracy: 0.7814
# > 77.170
# 100/100 [==============================] - 24s 236ms/step - loss: 0.6113 - accuracy: 0.8063 - val_loss: 0.5610 - val_accuracy: 0.8149
# > 80.750
# 100/100 [==============================] - 24s 235ms/step - loss: 0.5961 - accuracy: 0.8102 - val_loss: 0.6355 - val_accuracy: 0.7831
# 100/100 [==============================] - 23s 234ms/step - loss: 0.5810 - accuracy: 0.8162 - val_loss: 0.6392 - val_accuracy: 0.7909
# 100/100 [==============================] - 23s 234ms/step - loss: 0.5678 - accuracy: 0.8196 - val_loss: 0.5994 - val_accuracy: 0.8031
# 100/100 [==============================] - 24s 236ms/step - loss: 0.5474 - accuracy: 0.8261 - val_loss: 0.6617 - val_accuracy: 0.7793
# 100/100 [==============================] - 23s 233ms/step - loss: 0.5371 - accuracy: 0.8304 - val_loss: 0.5837 - val_accuracy: 0.8083
# 100/100 [==============================] - 23s 234ms/step - loss: 0.5180 - accuracy: 0.8361 - val_loss: 0.5426 - val_accuracy: 0.8224
# > 81.270
# 100/100 [==============================] - 24s 237ms/step - loss: 0.5086 - accuracy: 0.8368 - val_loss: 0.5333 - val_accuracy: 0.8235
# > 82.140
# 100/100 [==============================] - 24s 234ms/step - loss: 0.5085 - accuracy: 0.8396 - val_loss: 0.5293 - val_accuracy: 0.8267
# 100/100 [==============================] - 24s 236ms/step - loss: 0.4988 - accuracy: 0.8409 - val_loss: 0.4996 - val_accuracy: 0.8300
# > 82.570
# 100/100 [==============================] - 23s 234ms/step - loss: 0.4816 - accuracy: 0.8479 - val_loss: 0.4976 - val_accuracy: 0.8319
# > 82.870
# 100/100 [==============================] - 23s 234ms/step - loss: 0.4744 - accuracy: 0.8486 - val_loss: 0.5484 - val_accuracy: 0.8144
# 100/100 [==============================] - 23s 232ms/step - loss: 0.4648 - accuracy: 0.8510 - val_loss: 0.4965 - val_accuracy: 0.8393
# 100/100 [==============================] - 24s 236ms/step - loss: 0.4508 - accuracy: 0.8569 - val_loss: 0.4832 - val_accuracy: 0.8428
# > 83.960
# 100/100 [==============================] - 24s 235ms/step - loss: 0.4501 - accuracy: 0.8596 - val_loss: 0.5022 - val_accuracy: 0.8419
# > 84.010
# 100/100 [==============================] - 23s 234ms/step - loss: 0.4372 - accuracy: 0.8590 - val_loss: 0.5653 - val_accuracy: 0.8172
# 100/100 [==============================] - 23s 233ms/step - loss: 0.4295 - accuracy: 0.8648 - val_loss: 0.5403 - val_accuracy: 0.8279
# 100/100 [==============================] - 23s 233ms/step - loss: 0.4298 - accuracy: 0.8631 - val_loss: 0.4570 - val_accuracy: 0.8516
# > 84.710
# 100/100 [==============================] - 23s 233ms/step - loss: 0.4093 - accuracy: 0.8714 - val_loss: 0.4247 - val_accuracy: 0.8601
# > 86.200
# 100/100 [==============================] - 23s 234ms/step - loss: 0.4138 - accuracy: 0.8694 - val_loss: 0.3833 - val_accuracy: 0.8696
# > 86.660
# 100/100 [==============================] - 24s 236ms/step - loss: 0.4031 - accuracy: 0.8710 - val_loss: 0.4432 - val_accuracy: 0.8624
# 100/100 [==============================] - 23s 233ms/step - loss: 0.4007 - accuracy: 0.8738 - val_loss: 0.4433 - val_accuracy: 0.8547
# 100/100 [==============================] - 24s 235ms/step - loss: 0.3972 - accuracy: 0.8734 - val_loss: 0.4247 - val_accuracy: 0.8621
# 100/100 [==============================] - 23s 234ms/step - loss: 0.3847 - accuracy: 0.8772 - val_loss: 0.4114 - val_accuracy: 0.8661
# 100/100 [==============================] - 24s 234ms/step - loss: 0.3748 - accuracy: 0.8783 - val_loss: 0.4331 - val_accuracy: 0.8586
# 100/100 [==============================] - 23s 233ms/step - loss: 0.3704 - accuracy: 0.8824 - val_loss: 0.4569 - val_accuracy: 0.8555
# 100/100 [==============================] - 23s 233ms/step - loss: 0.3741 - accuracy: 0.8827 - val_loss: 0.5632 - val_accuracy: 0.8285
# 100/100 [==============================] - 24s 235ms/step - loss: 0.3644 - accuracy: 0.8853 - val_loss: 0.4302 - val_accuracy: 0.8638
# 100/100 [==============================] - 24s 235ms/step - loss: 0.3554 - accuracy: 0.8873 - val_loss: 0.5231 - val_accuracy: 0.8414
# 100/100 [==============================] - 24s 239ms/step - loss: 0.3565 - accuracy: 0.8867 - val_loss: 0.4655 - val_accuracy: 0.8555
# 100/100 [==============================] - 24s 236ms/step - loss: 0.3482 - accuracy: 0.8901 - val_loss: 0.4885 - val_accuracy: 0.8445
# 100/100 [==============================] - 23s 233ms/step - loss: 0.3457 - accuracy: 0.8907 - val_loss: 0.5148 - val_accuracy: 0.8447
# 100/100 [==============================] - 24s 236ms/step - loss: 0.3462 - accuracy: 0.8909 - val_loss: 0.3905 - val_accuracy: 0.8706
# 100/100 [==============================] - 23s 234ms/step - loss: 0.3341 - accuracy: 0.8942 - val_loss: 0.4107 - val_accuracy: 0.8682
# 100/100 [==============================] - 24s 237ms/step - loss: 0.3267 - accuracy: 0.8967 - val_loss: 0.4456 - val_accuracy: 0.8567
# 100/100 [==============================] - 23s 232ms/step - loss: 0.3245 - accuracy: 0.8946 - val_loss: 0.4332 - val_accuracy: 0.8658
# 100/100 [==============================] - 23s 233ms/step - loss: 0.3299 - accuracy: 0.8944 - val_loss: 0.4330 - val_accuracy: 0.8642
# 100/100 [==============================] - 23s 234ms/step - loss: 0.3175 - accuracy: 0.8986 - val_loss: 0.3838 - val_accuracy: 0.8794
# > 87.080
# 100/100 [==============================] - 23s 234ms/step - loss: 0.3191 - accuracy: 0.8989 - val_loss: 0.4492 - val_accuracy: 0.8676
# 100/100 [==============================] - 24s 235ms/step - loss: 0.3123 - accuracy: 0.9000 - val_loss: 0.3667 - val_accuracy: 0.8814
# > 87.580
# 100/100 [==============================] - 23s 231ms/step - loss: 0.3053 - accuracy: 0.8999 - val_loss: 0.4225 - val_accuracy: 0.8655
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2990 - accuracy: 0.9050 - val_loss: 0.3471 - val_accuracy: 0.8880
# > 88.710
# 100/100 [==============================] - 24s 235ms/step - loss: 0.2976 - accuracy: 0.9040 - val_loss: 0.4029 - val_accuracy: 0.8712
# 100/100 [==============================] - 23s 232ms/step - loss: 0.2908 - accuracy: 0.9067 - val_loss: 0.4192 - val_accuracy: 0.8717
# 100/100 [==============================] - 24s 236ms/step - loss: 0.3001 - accuracy: 0.9065 - val_loss: 0.4240 - val_accuracy: 0.8686
# 100/100 [==============================] - 24s 235ms/step - loss: 0.2955 - accuracy: 0.9052 - val_loss: 0.4088 - val_accuracy: 0.8706
# 100/100 [==============================] - 24s 235ms/step - loss: 0.2900 - accuracy: 0.9076 - val_loss: 0.4480 - val_accuracy: 0.8628
# 100/100 [==============================] - 23s 231ms/step - loss: 0.2748 - accuracy: 0.9115 - val_loss: 0.3563 - val_accuracy: 0.8874
# 100/100 [==============================] - 23s 232ms/step - loss: 0.2799 - accuracy: 0.9113 - val_loss: 0.3873 - val_accuracy: 0.8778
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2704 - accuracy: 0.9138 - val_loss: 0.3496 - val_accuracy: 0.8885
# 100/100 [==============================] - 23s 232ms/step - loss: 0.2721 - accuracy: 0.9135 - val_loss: 0.4232 - val_accuracy: 0.8727
# 100/100 [==============================] - 24s 235ms/step - loss: 0.2714 - accuracy: 0.9137 - val_loss: 0.3679 - val_accuracy: 0.8872
# 100/100 [==============================] - 23s 231ms/step - loss: 0.2659 - accuracy: 0.9151 - val_loss: 0.3607 - val_accuracy: 0.8786
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2642 - accuracy: 0.9163 - val_loss: 0.3761 - val_accuracy: 0.8836
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2632 - accuracy: 0.9159 - val_loss: 0.3994 - val_accuracy: 0.8788
# 100/100 [==============================] - 23s 232ms/step - loss: 0.2606 - accuracy: 0.9188 - val_loss: 0.3452 - val_accuracy: 0.8958
# > 89.040
# 100/100 [==============================] - 24s 236ms/step - loss: 0.2487 - accuracy: 0.9194 - val_loss: 0.3575 - val_accuracy: 0.8897
# 100/100 [==============================] - 23s 232ms/step - loss: 0.2536 - accuracy: 0.9191 - val_loss: 0.4317 - val_accuracy: 0.8741
# 100/100 [==============================] - 24s 236ms/step - loss: 0.2493 - accuracy: 0.9187 - val_loss: 0.4064 - val_accuracy: 0.8774
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2427 - accuracy: 0.9227 - val_loss: 0.3788 - val_accuracy: 0.8855
# 100/100 [==============================] - 23s 231ms/step - loss: 0.2421 - accuracy: 0.9242 - val_loss: 0.3305 - val_accuracy: 0.8980
# 100/100 [==============================] - 24s 234ms/step - loss: 0.2447 - accuracy: 0.9229 - val_loss: 0.4227 - val_accuracy: 0.8724
# 100/100 [==============================] - 23s 231ms/step - loss: 0.2487 - accuracy: 0.9237 - val_loss: 0.3160 - val_accuracy: 0.8965
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2347 - accuracy: 0.9260 - val_loss: 0.3566 - val_accuracy: 0.8909
# 100/100 [==============================] - 23s 232ms/step - loss: 0.2386 - accuracy: 0.9249 - val_loss: 0.3783 - val_accuracy: 0.8822
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2326 - accuracy: 0.9265 - val_loss: 0.3801 - val_accuracy: 0.8806
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2340 - accuracy: 0.9263 - val_loss: 0.3559 - val_accuracy: 0.8902
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2267 - accuracy: 0.9291 - val_loss: 0.3818 - val_accuracy: 0.8836
# 100/100 [==============================] - 24s 237ms/step - loss: 0.2350 - accuracy: 0.9268 - val_loss: 0.3756 - val_accuracy: 0.8834
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2262 - accuracy: 0.9278 - val_loss: 0.4372 - val_accuracy: 0.8814
# 100/100 [==============================] - 24s 235ms/step - loss: 0.2333 - accuracy: 0.9235 - val_loss: 0.4501 - val_accuracy: 0.8711
# 100/100 [==============================] - 24s 235ms/step - loss: 0.2265 - accuracy: 0.9269 - val_loss: 0.4377 - val_accuracy: 0.8710
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2228 - accuracy: 0.9297 - val_loss: 0.3440 - val_accuracy: 0.8938
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2195 - accuracy: 0.9312 - val_loss: 0.3912 - val_accuracy: 0.8829
# 100/100 [==============================] - 23s 234ms/step - loss: 0.2146 - accuracy: 0.9323 - val_loss: 0.3542 - val_accuracy: 0.8948
# > 89.380
# 100/100 [==============================] - 24s 236ms/step - loss: 0.2099 - accuracy: 0.9327 - val_loss: 0.3266 - val_accuracy: 0.8997
# > 89.540
# 100/100 [==============================] - 24s 235ms/step - loss: 0.2115 - accuracy: 0.9333 - val_loss: 0.3338 - val_accuracy: 0.8987
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2084 - accuracy: 0.9345 - val_loss: 0.4457 - val_accuracy: 0.8770
# 100/100 [==============================] - 24s 236ms/step - loss: 0.2085 - accuracy: 0.9334 - val_loss: 0.3716 - val_accuracy: 0.8864
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2116 - accuracy: 0.9331 - val_loss: 0.4285 - val_accuracy: 0.8827
# 100/100 [==============================] - 24s 235ms/step - loss: 0.2050 - accuracy: 0.9345 - val_loss: 0.3239 - val_accuracy: 0.8998
# > 89.620
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2091 - accuracy: 0.9348 - val_loss: 0.3487 - val_accuracy: 0.8957
# 100/100 [==============================] - 24s 236ms/step - loss: 0.2065 - accuracy: 0.9359 - val_loss: 0.3773 - val_accuracy: 0.8870
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1966 - accuracy: 0.9383 - val_loss: 0.3786 - val_accuracy: 0.8852
# 100/100 [==============================] - 23s 233ms/step - loss: 0.2079 - accuracy: 0.9348 - val_loss: 0.3495 - val_accuracy: 0.8976
# 100/100 [==============================] - 23s 230ms/step - loss: 0.2041 - accuracy: 0.9351 - val_loss: 0.3219 - val_accuracy: 0.9017
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1967 - accuracy: 0.9388 - val_loss: 0.3847 - val_accuracy: 0.8869
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1885 - accuracy: 0.9399 - val_loss: 0.3392 - val_accuracy: 0.9008
# > 89.650
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1958 - accuracy: 0.9391 - val_loss: 0.3656 - val_accuracy: 0.8915
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1902 - accuracy: 0.9395 - val_loss: 0.3369 - val_accuracy: 0.8987
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1919 - accuracy: 0.9398 - val_loss: 0.3239 - val_accuracy: 0.9009
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1824 - accuracy: 0.9420 - val_loss: 0.3879 - val_accuracy: 0.8799
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1872 - accuracy: 0.9410 - val_loss: 0.4166 - val_accuracy: 0.8767
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1797 - accuracy: 0.9424 - val_loss: 0.3812 - val_accuracy: 0.8893
# 100/100 [==============================] - 23s 230ms/step - loss: 0.1811 - accuracy: 0.9422 - val_loss: 0.3459 - val_accuracy: 0.9009
# 100/100 [==============================] - 23s 230ms/step - loss: 0.1790 - accuracy: 0.9437 - val_loss: 0.3921 - val_accuracy: 0.8824
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1753 - accuracy: 0.9439 - val_loss: 0.3836 - val_accuracy: 0.8882
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1760 - accuracy: 0.9439 - val_loss: 0.3053 - val_accuracy: 0.9047
# > 90.200
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1805 - accuracy: 0.9427 - val_loss: 0.4395 - val_accuracy: 0.8790
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1861 - accuracy: 0.9424 - val_loss: 0.4378 - val_accuracy: 0.8753
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1790 - accuracy: 0.9426 - val_loss: 0.3484 - val_accuracy: 0.8991
# 100/100 [==============================] - 23s 232ms/step - loss: 0.2230 - accuracy: 0.9327 - val_loss: 0.3668 - val_accuracy: 0.8929
# 100/100 [==============================] - 23s 230ms/step - loss: 0.1892 - accuracy: 0.9401 - val_loss: 0.3365 - val_accuracy: 0.8987
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1814 - accuracy: 0.9429 - val_loss: 0.3750 - val_accuracy: 0.8910
# 100/100 [==============================] - 24s 235ms/step - loss: 0.1836 - accuracy: 0.9419 - val_loss: 0.3327 - val_accuracy: 0.8981
# 100/100 [==============================] - 23s 229ms/step - loss: 0.1681 - accuracy: 0.9468 - val_loss: 0.3577 - val_accuracy: 0.8952
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1747 - accuracy: 0.9445 - val_loss: 0.3993 - val_accuracy: 0.8939
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1766 - accuracy: 0.9438 - val_loss: 0.4403 - val_accuracy: 0.8780
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1678 - accuracy: 0.9464 - val_loss: 0.3582 - val_accuracy: 0.9017
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1671 - accuracy: 0.9460 - val_loss: 0.3546 - val_accuracy: 0.8952
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1679 - accuracy: 0.9470 - val_loss: 0.3567 - val_accuracy: 0.8989
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1664 - accuracy: 0.9473 - val_loss: 0.4032 - val_accuracy: 0.8908
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1617 - accuracy: 0.9492 - val_loss: 0.3785 - val_accuracy: 0.8933
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1631 - accuracy: 0.9493 - val_loss: 0.3831 - val_accuracy: 0.8928
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1599 - accuracy: 0.9500 - val_loss: 0.4077 - val_accuracy: 0.8914
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1580 - accuracy: 0.9499 - val_loss: 0.4013 - val_accuracy: 0.8906
# 100/100 [==============================] - 23s 234ms/step - loss: 0.1613 - accuracy: 0.9493 - val_loss: 0.3357 - val_accuracy: 0.8987
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1610 - accuracy: 0.9490 - val_loss: 0.3339 - val_accuracy: 0.8983
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1480 - accuracy: 0.9526 - val_loss: 0.4210 - val_accuracy: 0.8836
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1475 - accuracy: 0.9536 - val_loss: 0.3265 - val_accuracy: 0.9029
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1513 - accuracy: 0.9539 - val_loss: 0.3629 - val_accuracy: 0.8961
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1506 - accuracy: 0.9537 - val_loss: 0.4168 - val_accuracy: 0.8916
# 100/100 [==============================] - 23s 228ms/step - loss: 0.1505 - accuracy: 0.9531 - val_loss: 0.3389 - val_accuracy: 0.9025
# 100/100 [==============================] - 24s 234ms/step - loss: 0.1472 - accuracy: 0.9529 - val_loss: 0.4052 - val_accuracy: 0.8922
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1511 - accuracy: 0.9531 - val_loss: 0.3672 - val_accuracy: 0.8971
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1420 - accuracy: 0.9557 - val_loss: 0.3432 - val_accuracy: 0.9002
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1443 - accuracy: 0.9549 - val_loss: 0.4089 - val_accuracy: 0.8891
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1484 - accuracy: 0.9554 - val_loss: 0.3434 - val_accuracy: 0.8977
# 100/100 [==============================] - 24s 236ms/step - loss: 0.1573 - accuracy: 0.9520 - val_loss: 0.3507 - val_accuracy: 0.8982
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1588 - accuracy: 0.9517 - val_loss: 0.3848 - val_accuracy: 0.8949
# 100/100 [==============================] - 24s 235ms/step - loss: 0.1533 - accuracy: 0.9525 - val_loss: 0.3800 - val_accuracy: 0.8969
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1563 - accuracy: 0.9513 - val_loss: 0.3912 - val_accuracy: 0.8846
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1467 - accuracy: 0.9532 - val_loss: 0.3845 - val_accuracy: 0.8974
# 100/100 [==============================] - 24s 235ms/step - loss: 0.1455 - accuracy: 0.9544 - val_loss: 0.3429 - val_accuracy: 0.9020
# 100/100 [==============================] - 23s 234ms/step - loss: 0.1468 - accuracy: 0.9557 - val_loss: 0.3132 - val_accuracy: 0.9064
# 100/100 [==============================] - 24s 237ms/step - loss: 0.1398 - accuracy: 0.9554 - val_loss: 0.3464 - val_accuracy: 0.9017
# 100/100 [==============================] - 24s 238ms/step - loss: 0.1419 - accuracy: 0.9556 - val_loss: 0.3413 - val_accuracy: 0.9027
# > 90.270
# 100/100 [==============================] - 24s 235ms/step - loss: 0.1404 - accuracy: 0.9561 - val_loss: 0.3819 - val_accuracy: 0.8972
# 100/100 [==============================] - 23s 234ms/step - loss: 0.1302 - accuracy: 0.9585 - val_loss: 0.3363 - val_accuracy: 0.9021
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1353 - accuracy: 0.9589 - val_loss: 0.3907 - val_accuracy: 0.8864
# 100/100 [==============================] - 24s 236ms/step - loss: 0.1350 - accuracy: 0.9562 - val_loss: 0.3499 - val_accuracy: 0.9059
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1398 - accuracy: 0.9569 - val_loss: 0.3518 - val_accuracy: 0.9010
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1718 - accuracy: 0.9477 - val_loss: 0.3610 - val_accuracy: 0.8961
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1598 - accuracy: 0.9510 - val_loss: 0.3283 - val_accuracy: 0.9002
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1653 - accuracy: 0.9538 - val_loss: 0.3972 - val_accuracy: 0.8756
# 100/100 [==============================] - 24s 235ms/step - loss: 0.1845 - accuracy: 0.9437 - val_loss: 0.3400 - val_accuracy: 0.8979
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1414 - accuracy: 0.9546 - val_loss: 0.3545 - val_accuracy: 0.9011
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1402 - accuracy: 0.9565 - val_loss: 0.3357 - val_accuracy: 0.9061
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1410 - accuracy: 0.9577 - val_loss: 0.4005 - val_accuracy: 0.8891
# 100/100 [==============================] - 23s 234ms/step - loss: 0.1274 - accuracy: 0.9603 - val_loss: 0.3289 - val_accuracy: 0.9090
# > 90.380
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1351 - accuracy: 0.9579 - val_loss: 0.3550 - val_accuracy: 0.8982
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1358 - accuracy: 0.9582 - val_loss: 0.3296 - val_accuracy: 0.9053
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1329 - accuracy: 0.9571 - val_loss: 0.3084 - val_accuracy: 0.9096
# > 90.750
# 100/100 [==============================] - 25s 235ms/step - loss: 0.1266 - accuracy: 0.9599 - val_loss: 0.3103 - val_accuracy: 0.9103
# > 90.830
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1216 - accuracy: 0.9601 - val_loss: 0.3127 - val_accuracy: 0.9109
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1187 - accuracy: 0.9625 - val_loss: 0.3141 - val_accuracy: 0.9105
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1200 - accuracy: 0.9632 - val_loss: 0.3144 - val_accuracy: 0.9102
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1161 - accuracy: 0.9640 - val_loss: 0.3143 - val_accuracy: 0.9097
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1187 - accuracy: 0.9626 - val_loss: 0.3147 - val_accuracy: 0.9098
# 100/100 [==============================] - 24s 237ms/step - loss: 0.1161 - accuracy: 0.9641 - val_loss: 0.3140 - val_accuracy: 0.9096
# 100/100 [==============================] - 24s 238ms/step - loss: 0.1155 - accuracy: 0.9643 - val_loss: 0.3145 - val_accuracy: 0.9097
# 100/100 [==============================] - 24s 237ms/step - loss: 0.1159 - accuracy: 0.9633 - val_loss: 0.3146 - val_accuracy: 0.9097
# 100/100 [==============================] - 24s 235ms/step - loss: 0.1147 - accuracy: 0.9637 - val_loss: 0.3139 - val_accuracy: 0.9099
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1085 - accuracy: 0.9656 - val_loss: 0.3145 - val_accuracy: 0.9101
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1183 - accuracy: 0.9624 - val_loss: 0.3149 - val_accuracy: 0.9096
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1170 - accuracy: 0.9633 - val_loss: 0.3148 - val_accuracy: 0.9099
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1183 - accuracy: 0.9626 - val_loss: 0.3141 - val_accuracy: 0.9101
# 100/100 [==============================] - 23s 230ms/step - loss: 0.1116 - accuracy: 0.9650 - val_loss: 0.3144 - val_accuracy: 0.9101
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1119 - accuracy: 0.9643 - val_loss: 0.3145 - val_accuracy: 0.9102
# 100/100 [==============================] - 24s 235ms/step - loss: 0.1162 - accuracy: 0.9643 - val_loss: 0.3143 - val_accuracy: 0.9105
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1114 - accuracy: 0.9648 - val_loss: 0.3145 - val_accuracy: 0.9107
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1141 - accuracy: 0.9638 - val_loss: 0.3142 - val_accuracy: 0.9105
# 100/100 [==============================] - 23s 234ms/step - loss: 0.1111 - accuracy: 0.9652 - val_loss: 0.3145 - val_accuracy: 0.9105
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1145 - accuracy: 0.9640 - val_loss: 0.3148 - val_accuracy: 0.9105
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1153 - accuracy: 0.9639 - val_loss: 0.3151 - val_accuracy: 0.9107
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1144 - accuracy: 0.9648 - val_loss: 0.3146 - val_accuracy: 0.9106
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1136 - accuracy: 0.9647 - val_loss: 0.3147 - val_accuracy: 0.9109
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1137 - accuracy: 0.9654 - val_loss: 0.3149 - val_accuracy: 0.9106
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1097 - accuracy: 0.9651 - val_loss: 0.3150 - val_accuracy: 0.9109
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1132 - accuracy: 0.9645 - val_loss: 0.3145 - val_accuracy: 0.9105
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1067 - accuracy: 0.9658 - val_loss: 0.3154 - val_accuracy: 0.9108
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1141 - accuracy: 0.9643 - val_loss: 0.3148 - val_accuracy: 0.9110
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1087 - accuracy: 0.9654 - val_loss: 0.3146 - val_accuracy: 0.9112
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1183 - accuracy: 0.9631 - val_loss: 0.3139 - val_accuracy: 0.9110
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1113 - accuracy: 0.9655 - val_loss: 0.3139 - val_accuracy: 0.9110
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1136 - accuracy: 0.9644 - val_loss: 0.3139 - val_accuracy: 0.9114
# 100/100 [==============================] - 23s 230ms/step - loss: 0.1066 - accuracy: 0.9658 - val_loss: 0.3151 - val_accuracy: 0.9110
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1128 - accuracy: 0.9651 - val_loss: 0.3139 - val_accuracy: 0.9116
# 100/100 [==============================] - 24s 235ms/step - loss: 0.1161 - accuracy: 0.9638 - val_loss: 0.3152 - val_accuracy: 0.9116
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1112 - accuracy: 0.9646 - val_loss: 0.3153 - val_accuracy: 0.9108
# 100/100 [==============================] - 23s 234ms/step - loss: 0.1119 - accuracy: 0.9646 - val_loss: 0.3143 - val_accuracy: 0.9112
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1153 - accuracy: 0.9636 - val_loss: 0.3147 - val_accuracy: 0.9115
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1105 - accuracy: 0.9650 - val_loss: 0.3154 - val_accuracy: 0.9113
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1078 - accuracy: 0.9664 - val_loss: 0.3151 - val_accuracy: 0.9114
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1132 - accuracy: 0.9646 - val_loss: 0.3145 - val_accuracy: 0.9113
# 100/100 [==============================] - 23s 232ms/step - loss: 0.1122 - accuracy: 0.9654 - val_loss: 0.3148 - val_accuracy: 0.9110
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1109 - accuracy: 0.9655 - val_loss: 0.3144 - val_accuracy: 0.9110
# 100/100 [==============================] - 23s 233ms/step - loss: 0.1126 - accuracy: 0.9648 - val_loss: 0.3154 - val_accuracy: 0.9111
# 100/100 [==============================] - 24s 235ms/step - loss: 0.1139 - accuracy: 0.9641 - val_loss: 0.3161 - val_accuracy: 0.9106
# 100/100 [==============================] - 23s 231ms/step - loss: 0.1145 - accuracy: 0.9646 - val_loss: 0.3150 - val_accuracy: 0.9109

# %%
model.save('model_10.h5')

# %%
import tensorflow as tf
model = tf.keras.models.load_model('/content/model_prime.h5')

# %%
 _, acc = model.evaluate(test_generator, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 90.830

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
 _, acc = model.evaluate(train_generator, verbose=0)
print('TRAIN > %.3f' % (acc * 100.0))
 _, acc = model.evaluate(validation_generator, verbose=0)
print('TEST > %.3f' % (acc * 100.0))
 _, acc = model.evaluate(test_generator, verbose=0)
print('VALIDATION > %.3f' % (acc * 100.0))
# Out:
# TRAIN > 98.518
# TEST > 91.030
# VALIDATION > 90.830

# %%
#fig, ax = plt.subplots(2,1,figsize=(10,10))
#ax[0].set_title('Cross Entropy Loss', fontsize = 20)
#ax[0].plot(history_.history['loss'], color='blue', label='Train')
#ax[0].plot(history_.history['val_loss'], color='orange', label='Validation')
#ax[0].set_ylabel('Cross Entropy Loss', fontsize = 16)
#ax[0].legend(fontsize = 16)

#ax[1].set_title('Classification Accuracy', fontsize = 20)
#ax[1].plot(history_.history['accuracy'], color='blue', label='Train')
#ax[1].plot(history_.history['val_accuracy'], color='orange', label='Validation')
#ax[1].set_ylabel('Classification Accuracy', fontsize = 16)
#ax[1].set_xlabel('Epochs', fontsize = 16)
#ax[1].legend(fontsize = 16)

#plt.show()

# %%
#fig.savefig("modelo_"+str(MODELO)+".png")

# %%
model.save('model_10_prime.h5')

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test/255.0)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 8
num_cols = 3
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.savefig('predictions3.png')
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
