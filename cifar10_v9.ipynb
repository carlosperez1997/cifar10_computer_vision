# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import time
import datetime

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model

MODELO = 9

ANCHO_IMAGEN, ALTURA_IMAGEN, CANALES_IMAGENES = 32, 32, 3

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
    kernel_initializer='he_uniform', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.6))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', 
    kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Flatten())

model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.4))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 4,253,642
# Trainable params: 4,251,082
# Non-trainable params: 2,560
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
from tensorflow.keras.optimizers import Adam
from keras.optimizers import SGD

new_adam = Adam(learning_rate=2e-5)

opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

#x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %%
y_train_rshape = y_train.ravel()
y_val_rshape = y_val.ravel()
y_test_rshape = y_test.ravel()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train_rshape)
y_train_encoded = le.transform(y_train_rshape)
y_val_encoded = le.transform(y_val_rshape)
y_test_encoded = le.transform(y_test_rshape)

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
#x_train_features_vgg = llevar_imagenes_cuellobotella(vgg_model, x_train)
#x_val_features_vgg = llevar_imagenes_cuellobotella(vgg_model, x_val)
#x_test_features_vgg = llevar_imagenes_cuellobotella(vgg_model, x_test)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    zoom_range=0.1,
    shear_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.15,
    height_shift_range=0.15,
    )

train_generator = train_datagen.flow(
    x_train, 
    y_train_encoded, 
    batch_size=400
)

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=100
)

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=100
)

# %%
sample = 451
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train_encoded[sample:sample+1],
    batch_size=20
)

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
  plt.subplot(5,3,i+1)
  for X, y in example_generator:
    image = X[0]
    plt.imshow(image)
    plt.title(y[0])
    break

plt.tight_layout()
plt.savefig('data_aug.png')
plt.show()

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback = EarlyStopping(monitor='val_loss', patience=15)

# %%
t = time.perf_counter()

# %%
history = model.fit(train_generator, steps_per_epoch = 100, 
                    validation_steps=100, use_multiprocessing=False,
                    epochs=300, validation_data=validation_generator,
                    callbacks=[callback])

#history = model.fit(x_train, y_train, epochs=300, 
#                    use_multiprocessing=False, batch_size= 512, 
#                    callbacks=[callback], 
#                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2705 - accuracy: 0.9079 - val_loss: 0.4448 - val_accuracy: 0.8684
# Epoch 2/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2800 - accuracy: 0.9046 - val_loss: 0.4260 - val_accuracy: 0.8726
# Epoch 3/300
# 100/100 [==============================] - 23s 227ms/step - loss: 0.2723 - accuracy: 0.9058 - val_loss: 0.4000 - val_accuracy: 0.8760
# Epoch 4/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2689 - accuracy: 0.9068 - val_loss: 0.4305 - val_accuracy: 0.8779
# Epoch 5/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2681 - accuracy: 0.9087 - val_loss: 0.4699 - val_accuracy: 0.8663
# Epoch 6/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2665 - accuracy: 0.9082 - val_loss: 0.5693 - val_accuracy: 0.8320
# Epoch 7/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.3042 - accuracy: 0.8985 - val_loss: 0.4169 - val_accuracy: 0.8763
# Epoch 8/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2719 - accuracy: 0.9052 - val_loss: 0.4545 - val_accuracy: 0.8690
# Epoch 9/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2706 - accuracy: 0.9072 - val_loss: 0.3673 - val_accuracy: 0.8907
# Epoch 10/300
# 100/100 [==============================] - 22s 224ms/step - loss: 0.2629 - accuracy: 0.9106 - val_loss: 0.4606 - val_accuracy: 0.8693
# Epoch 11/300
# 100/100 [==============================] - 23s 227ms/step - loss: 0.2585 - accuracy: 0.9122 - val_loss: 0.4306 - val_accuracy: 0.8741
# Epoch 12/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2628 - accuracy: 0.9112 - val_loss: 0.3963 - val_accuracy: 0.8776
# Epoch 13/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2603 - accuracy: 0.9116 - val_loss: 0.3569 - val_accuracy: 0.8887
# Epoch 14/300
# 100/100 [==============================] - 22s 224ms/step - loss: 0.2648 - accuracy: 0.9102 - val_loss: 0.3838 - val_accuracy: 0.8832
# Epoch 15/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2706 - accuracy: 0.9130 - val_loss: 0.4752 - val_accuracy: 0.8631
# Epoch 16/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2584 - accuracy: 0.9125 - val_loss: 0.3760 - val_accuracy: 0.8833
# Epoch 17/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2583 - accuracy: 0.9099 - val_loss: 0.4027 - val_accuracy: 0.8755
# Epoch 18/300
# 100/100 [==============================] - 23s 227ms/step - loss: 0.2502 - accuracy: 0.9155 - val_loss: 0.4318 - val_accuracy: 0.8716
# Epoch 19/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2588 - accuracy: 0.9138 - val_loss: 0.4325 - val_accuracy: 0.8776
# Epoch 20/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2576 - accuracy: 0.9128 - val_loss: 0.3955 - val_accuracy: 0.8810
# Epoch 21/300
# 100/100 [==============================] - 22s 224ms/step - loss: 0.3843 - accuracy: 0.8773 - val_loss: 0.5985 - val_accuracy: 0.8062
# Epoch 22/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.3109 - accuracy: 0.8958 - val_loss: 0.8004 - val_accuracy: 0.7680
# Epoch 23/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2830 - accuracy: 0.9035 - val_loss: 0.4506 - val_accuracy: 0.8641
# Epoch 24/300
# 100/100 [==============================] - 22s 224ms/step - loss: 0.2665 - accuracy: 0.9066 - val_loss: 0.4078 - val_accuracy: 0.8826
# Epoch 25/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.3297 - accuracy: 0.8895 - val_loss: 0.5204 - val_accuracy: 0.8434
# Epoch 26/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.3225 - accuracy: 0.8924 - val_loss: 0.4419 - val_accuracy: 0.8636
# Epoch 27/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2957 - accuracy: 0.9012 - val_loss: 0.4192 - val_accuracy: 0.8776
# Epoch 28/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2846 - accuracy: 0.9060 - val_loss: 0.4601 - val_accuracy: 0.8626

# %%
opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_generator, steps_per_epoch = 100, 
                    validation_steps=100, use_multiprocessing=False,
                    epochs=300, validation_data=validation_generator,
                    callbacks=[callback])
# Out:
# Epoch 1/300
# 100/100 [==============================] - 24s 229ms/step - loss: 0.2783 - accuracy: 0.9060 - val_loss: 0.4336 - val_accuracy: 0.8710
# Epoch 2/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2470 - accuracy: 0.9144 - val_loss: 0.3868 - val_accuracy: 0.8851
# Epoch 3/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2626 - accuracy: 0.9111 - val_loss: 0.3714 - val_accuracy: 0.8892
# Epoch 4/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2594 - accuracy: 0.9134 - val_loss: 0.4088 - val_accuracy: 0.8799
# Epoch 5/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2563 - accuracy: 0.9138 - val_loss: 0.4043 - val_accuracy: 0.8819
# Epoch 6/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2515 - accuracy: 0.9153 - val_loss: 0.3773 - val_accuracy: 0.8900
# Epoch 7/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2432 - accuracy: 0.9158 - val_loss: 0.3817 - val_accuracy: 0.8893
# Epoch 8/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2397 - accuracy: 0.9168 - val_loss: 0.3533 - val_accuracy: 0.8958
# Epoch 9/300
# 100/100 [==============================] - 23s 227ms/step - loss: 0.2476 - accuracy: 0.9179 - val_loss: 0.4013 - val_accuracy: 0.8828
# Epoch 10/300
# 100/100 [==============================] - 23s 227ms/step - loss: 0.2468 - accuracy: 0.9138 - val_loss: 0.4316 - val_accuracy: 0.8764
# Epoch 11/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2434 - accuracy: 0.9164 - val_loss: 0.4242 - val_accuracy: 0.8781
# Epoch 12/300
# 100/100 [==============================] - 23s 227ms/step - loss: 0.2435 - accuracy: 0.9189 - val_loss: 0.3856 - val_accuracy: 0.8864
# Epoch 13/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2535 - accuracy: 0.9143 - val_loss: 0.4001 - val_accuracy: 0.8835
# Epoch 14/300
# 100/100 [==============================] - 22s 224ms/step - loss: 0.2466 - accuracy: 0.9160 - val_loss: 0.3700 - val_accuracy: 0.8889
# Epoch 15/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2585 - accuracy: 0.9145 - val_loss: 0.3742 - val_accuracy: 0.8883
# Epoch 16/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2364 - accuracy: 0.9187 - val_loss: 0.7670 - val_accuracy: 0.7604
# Epoch 17/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2796 - accuracy: 0.9040 - val_loss: 0.3840 - val_accuracy: 0.8877
# Epoch 18/300
# 100/100 [==============================] - 22s 224ms/step - loss: 0.2557 - accuracy: 0.9145 - val_loss: 0.3672 - val_accuracy: 0.8895
# Epoch 19/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2533 - accuracy: 0.9157 - val_loss: 0.3963 - val_accuracy: 0.8846
# Epoch 20/300
# 100/100 [==============================] - 23s 225ms/step - loss: 0.2495 - accuracy: 0.9136 - val_loss: 0.3711 - val_accuracy: 0.8912
# Epoch 21/300
# 100/100 [==============================] - 23s 226ms/step - loss: 0.2511 - accuracy: 0.9127 - val_loss: 0.3561 - val_accuracy: 0.8944
# Epoch 22/300
# 100/100 [==============================] - 23s 227ms/step - loss: 0.2509 - accuracy: 0.9146 - val_loss: 0.4023 - val_accuracy: 0.8825
# Epoch 23/300
# 100/100 [==============================] - 23s 228ms/step - loss: 0.2477 - accuracy: 0.9143 - val_loss: 0.3820 - val_accuracy: 0.8879

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:41:45.864786

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(test_generator, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 88.450

# %%
fig, ax = plt.subplots(2,1,figsize=(10,10))
ax[0].set_title('Cross Entropy Loss', fontsize = 20)
ax[0].plot(history.history['loss'], color='blue', label='Train')
ax[0].plot(history.history['val_loss'], color='orange', label='Validation')
ax[0].set_ylabel('Cross Entropy Loss', fontsize = 16)
ax[0].legend(fontsize = 16)

ax[1].set_title('Classification Accuracy', fontsize = 20)
ax[1].plot(history.history['accuracy'], color='blue', label='Train')
ax[1].plot(history.history['val_accuracy'], color='orange', label='Validation')
ax[1].set_ylabel('Classification Accuracy', fontsize = 16)
ax[1].set_xlabel('Epochs', fontsize = 16)
ax[1].legend(fontsize = 16)

plt.show()

# %%
fig.savefig("modelo_"+str(MODELO)+".png")

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
