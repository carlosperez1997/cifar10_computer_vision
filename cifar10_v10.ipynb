# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import time
import datetime

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model

MODELO = 10

ANCHO_IMAGEN, ALTURA_IMAGEN, CANALES_IMAGENES = 32, 32, 3

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
    kernel_initializer='he_uniform', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.6))

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', 
    kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))

model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation= 'relu', kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.4))

model.add(ks.layers.Flatten())

model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.4))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.4))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 5,555,338
# Trainable params: 5,551,882
# Non-trainable params: 3,456
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
from tensorflow.keras.optimizers import Adam
from keras.optimizers import SGD

new_adam = Adam(learning_rate=2e-5)

opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

#x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
y_train_label = y_train

#y_test = ks.utils.to_categorical(y_test)
#y_train = ks.utils.to_categorical(y_train)

y_test
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %%
y_train_rshape = y_train.ravel()
y_val_rshape = y_val.ravel()
y_test_rshape = y_test.ravel()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train_rshape)
y_train_encoded = le.transform(y_train_rshape)
y_val_encoded = le.transform(y_val_rshape)
y_test_encoded = le.transform(y_test_rshape)

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
#x_train_features_vgg = llevar_imagenes_cuellobotella(vgg_model, x_train)
#x_val_features_vgg = llevar_imagenes_cuellobotella(vgg_model, x_val)
#x_test_features_vgg = llevar_imagenes_cuellobotella(vgg_model, x_test)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    zoom_range=0.1,
    shear_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.15,
    height_shift_range=0.15,
    )

train_generator = train_datagen.flow(
    x_train, 
    y_train_encoded, 
    batch_size=400
)

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=100
)

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=100
)

# %%
sample = 451
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train_encoded[sample:sample+1],
    batch_size=20
)

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
  plt.subplot(5,3,i+1)
  for X, y in example_generator:
    image = X[0]
    plt.imshow(image)
    plt.title(y[0])
    break

plt.tight_layout()
plt.savefig('data_aug.png')
plt.show()

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
callback = EarlyStopping(monitor='val_loss', patience=3)

# %%
t = time.perf_counter()

# %%
acc = 0

# %%
#from tensorflow.keras.models import load_model
#model = load_model('/content/model_10.h5')

# %%
#model = tf.keras.models.load_model('/content/model_10.h5')
#_, acc = model.evaluate(test_generator, verbose=0)

# %%
first = False
acc_max = 0
while acc < 0.897:
  # history = 
  model.fit(train_generator, steps_per_epoch = 100, 
                      validation_steps=100, use_multiprocessing=False,
                      epochs=1, validation_data=validation_generator,
                      callbacks=[callback])
  #history = model.fit(x_train, y_train, epochs=300, 
  #                  use_multiprocessing=False, batch_size= 512, 
  #                  callbacks=[callback], 
  #                  validation_data=(x_val, y_val))
  
  _, acc = model.evaluate(test_generator, verbose=0)

  if acc > acc_max:
    acc_max = acc
    model.save('model_10.h5')
    print('> %.3f' % (acc * 100.0))
# Out:
# 100/100 [==============================] - 31s 262ms/step - loss: 2.5022 - accuracy: 0.1360 - val_loss: 3.0210 - val_accuracy: 0.0982
# > 10.040
# 100/100 [==============================] - 26s 254ms/step - loss: 1.8716 - accuracy: 0.2720 - val_loss: 2.6319 - val_accuracy: 0.1442
# > 14.730
# 100/100 [==============================] - 26s 257ms/step - loss: 1.6939 - accuracy: 0.3602 - val_loss: 2.2156 - val_accuracy: 0.2652
# > 26.830
# 100/100 [==============================] - 26s 256ms/step - loss: 1.5613 - accuracy: 0.4191 - val_loss: 2.4326 - val_accuracy: 0.2666
# 100/100 [==============================] - 26s 256ms/step - loss: 1.4492 - accuracy: 0.4755 - val_loss: 1.9274 - val_accuracy: 0.3788
# > 37.630
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2869 - accuracy: 0.9083 - val_loss: 0.4197 - val_accuracy: 0.8689
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2941 - accuracy: 0.9071 - val_loss: 0.4356 - val_accuracy: 0.8660
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2755 - accuracy: 0.9129 - val_loss: 0.4249 - val_accuracy: 0.8737
# 100/100 [==============================] - 26s 258ms/step - loss: 0.2747 - accuracy: 0.9125 - val_loss: 0.3704 - val_accuracy: 0.8832
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2766 - accuracy: 0.9117 - val_loss: 0.3882 - val_accuracy: 0.8800
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2745 - accuracy: 0.9100 - val_loss: 0.3633 - val_accuracy: 0.8911
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2839 - accuracy: 0.9090 - val_loss: 0.4489 - val_accuracy: 0.8668
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2765 - accuracy: 0.9117 - val_loss: 0.3550 - val_accuracy: 0.8880
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2690 - accuracy: 0.9131 - val_loss: 0.3983 - val_accuracy: 0.8786
# 100/100 [==============================] - 26s 255ms/step - loss: 0.2740 - accuracy: 0.9119 - val_loss: 0.3645 - val_accuracy: 0.8882
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2671 - accuracy: 0.9156 - val_loss: 0.3391 - val_accuracy: 0.8949
# > 88.620
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2689 - accuracy: 0.9135 - val_loss: 0.3377 - val_accuracy: 0.8951
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2563 - accuracy: 0.9166 - val_loss: 0.3519 - val_accuracy: 0.8951
# > 88.630
# 100/100 [==============================] - 26s 258ms/step - loss: 0.2588 - accuracy: 0.9149 - val_loss: 0.3903 - val_accuracy: 0.8792
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2579 - accuracy: 0.9183 - val_loss: 0.3787 - val_accuracy: 0.8845
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2567 - accuracy: 0.9173 - val_loss: 0.3903 - val_accuracy: 0.8782
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2487 - accuracy: 0.9189 - val_loss: 0.3807 - val_accuracy: 0.8819
# 100/100 [==============================] - 26s 258ms/step - loss: 0.2523 - accuracy: 0.9197 - val_loss: 0.3238 - val_accuracy: 0.8978
# > 88.660
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2478 - accuracy: 0.9195 - val_loss: 0.4757 - val_accuracy: 0.8602
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2490 - accuracy: 0.9213 - val_loss: 0.3751 - val_accuracy: 0.8846
# 100/100 [==============================] - 26s 259ms/step - loss: 0.2436 - accuracy: 0.9212 - val_loss: 0.3942 - val_accuracy: 0.8851
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2383 - accuracy: 0.9243 - val_loss: 0.3446 - val_accuracy: 0.8954
# > 88.970
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2468 - accuracy: 0.9223 - val_loss: 0.3635 - val_accuracy: 0.8877
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2401 - accuracy: 0.9238 - val_loss: 0.3415 - val_accuracy: 0.8945
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2426 - accuracy: 0.9229 - val_loss: 0.3427 - val_accuracy: 0.8918
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2393 - accuracy: 0.9243 - val_loss: 0.3658 - val_accuracy: 0.8863
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2357 - accuracy: 0.9244 - val_loss: 0.3370 - val_accuracy: 0.8953
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2288 - accuracy: 0.9277 - val_loss: 0.3763 - val_accuracy: 0.8850
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2431 - accuracy: 0.9208 - val_loss: 0.3989 - val_accuracy: 0.8803
# 100/100 [==============================] - 26s 256ms/step - loss: 0.2292 - accuracy: 0.9270 - val_loss: 0.3348 - val_accuracy: 0.9001
# > 89.630

# %%
model.save('model_10.h5')

# %%
 _, acc = model.evaluate(test_generator, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 89.630

# %%
from tensorflow.keras.models import load_model
recovered_model = load_model('/content/model_10.h5')

# %%
callback = EarlyStopping(monitor='val_loss', patience=2)

# %%
opt = SGD(lr=0.0005) #momentum=0.6
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
acc_max = 0
while acc < 0.90:
  # history = 
  model.fit(train_generator, steps_per_epoch = 100, 
                      validation_steps=100, use_multiprocessing=False,
                      epochs=1, validation_data=validation_generator,
                      callbacks=[callback])
  #history = model.fit(x_train, y_train, epochs=300, 
  #                  use_multiprocessing=False, batch_size= 512, 
  #                  callbacks=[callback], 
  #                  validation_data=(x_val, y_val))
  
  _, acc = model.evaluate(test_generator, verbose=0)

  if acc > acc_max:
    acc_max = acc
    model.save('model_10_prime.h5')
    print('> %.3f' % (acc * 100.0))
# Out:
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1987 - accuracy: 0.9360 - val_loss: 0.3207 - val_accuracy: 0.8990
# > 89.760
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2062 - accuracy: 0.9341 - val_loss: 0.3215 - val_accuracy: 0.8991
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1980 - accuracy: 0.9364 - val_loss: 0.3224 - val_accuracy: 0.8987
# 100/100 [==============================] - 26s 260ms/step - loss: 0.2022 - accuracy: 0.9353 - val_loss: 0.3188 - val_accuracy: 0.8994
# > 89.820
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1965 - accuracy: 0.9358 - val_loss: 0.3202 - val_accuracy: 0.8981
# 100/100 [==============================] - 26s 258ms/step - loss: 0.2021 - accuracy: 0.9361 - val_loss: 0.3195 - val_accuracy: 0.8976
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1964 - accuracy: 0.9362 - val_loss: 0.3195 - val_accuracy: 0.8990
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1976 - accuracy: 0.9363 - val_loss: 0.3166 - val_accuracy: 0.8996
# 100/100 [==============================] - 26s 257ms/step - loss: 0.2014 - accuracy: 0.9357 - val_loss: 0.3198 - val_accuracy: 0.8998
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1924 - accuracy: 0.9384 - val_loss: 0.3175 - val_accuracy: 0.9001
# 100/100 [==============================] - 26s 255ms/step - loss: 0.1971 - accuracy: 0.9353 - val_loss: 0.3179 - val_accuracy: 0.8996
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1962 - accuracy: 0.9366 - val_loss: 0.3220 - val_accuracy: 0.8993
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1956 - accuracy: 0.9370 - val_loss: 0.3225 - val_accuracy: 0.8999
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1944 - accuracy: 0.9378 - val_loss: 0.3203 - val_accuracy: 0.9002
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1958 - accuracy: 0.9376 - val_loss: 0.3170 - val_accuracy: 0.9015
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1959 - accuracy: 0.9375 - val_loss: 0.3162 - val_accuracy: 0.9018
# > 89.910
# 100/100 [==============================] - 26s 255ms/step - loss: 0.1989 - accuracy: 0.9368 - val_loss: 0.3197 - val_accuracy: 0.9002
# 100/100 [==============================] - 26s 260ms/step - loss: 0.1947 - accuracy: 0.9374 - val_loss: 0.3185 - val_accuracy: 0.9010
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1917 - accuracy: 0.9373 - val_loss: 0.3192 - val_accuracy: 0.9003
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1965 - accuracy: 0.9369 - val_loss: 0.3193 - val_accuracy: 0.9003
# 100/100 [==============================] - 26s 262ms/step - loss: 0.1958 - accuracy: 0.9381 - val_loss: 0.3177 - val_accuracy: 0.9011
# 100/100 [==============================] - 26s 255ms/step - loss: 0.1947 - accuracy: 0.9381 - val_loss: 0.3172 - val_accuracy: 0.9013
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1913 - accuracy: 0.9385 - val_loss: 0.3175 - val_accuracy: 0.9005
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1881 - accuracy: 0.9388 - val_loss: 0.3175 - val_accuracy: 0.9012
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1925 - accuracy: 0.9384 - val_loss: 0.3159 - val_accuracy: 0.9016
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1958 - accuracy: 0.9371 - val_loss: 0.3176 - val_accuracy: 0.9011
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1919 - accuracy: 0.9356 - val_loss: 0.3202 - val_accuracy: 0.9006
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1862 - accuracy: 0.9382 - val_loss: 0.3164 - val_accuracy: 0.9018
# > 89.930
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1933 - accuracy: 0.9376 - val_loss: 0.3198 - val_accuracy: 0.9008
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1934 - accuracy: 0.9383 - val_loss: 0.3199 - val_accuracy: 0.9020
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1917 - accuracy: 0.9377 - val_loss: 0.3160 - val_accuracy: 0.9024
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1940 - accuracy: 0.9381 - val_loss: 0.3180 - val_accuracy: 0.9017
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1898 - accuracy: 0.9387 - val_loss: 0.3186 - val_accuracy: 0.9014
# 100/100 [==============================] - 26s 255ms/step - loss: 0.1859 - accuracy: 0.9401 - val_loss: 0.3214 - val_accuracy: 0.9018
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1906 - accuracy: 0.9374 - val_loss: 0.3165 - val_accuracy: 0.9026
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1934 - accuracy: 0.9384 - val_loss: 0.3178 - val_accuracy: 0.9023
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1902 - accuracy: 0.9385 - val_loss: 0.3193 - val_accuracy: 0.9021
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1945 - accuracy: 0.9381 - val_loss: 0.3156 - val_accuracy: 0.9021
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1902 - accuracy: 0.9390 - val_loss: 0.3145 - val_accuracy: 0.9028
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1855 - accuracy: 0.9395 - val_loss: 0.3162 - val_accuracy: 0.9030
# 100/100 [==============================] - 26s 255ms/step - loss: 0.1889 - accuracy: 0.9394 - val_loss: 0.3184 - val_accuracy: 0.9025
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1889 - accuracy: 0.9391 - val_loss: 0.3176 - val_accuracy: 0.9017
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1908 - accuracy: 0.9391 - val_loss: 0.3160 - val_accuracy: 0.9028
# > 89.980
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1864 - accuracy: 0.9403 - val_loss: 0.3188 - val_accuracy: 0.9019
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1871 - accuracy: 0.9393 - val_loss: 0.3164 - val_accuracy: 0.9024
# 100/100 [==============================] - 26s 255ms/step - loss: 0.1857 - accuracy: 0.9391 - val_loss: 0.3139 - val_accuracy: 0.9031
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1896 - accuracy: 0.9385 - val_loss: 0.3164 - val_accuracy: 0.9024
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1859 - accuracy: 0.9395 - val_loss: 0.3137 - val_accuracy: 0.9035
# > 90.020

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
 _, acc = model.evaluate(test_generator, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 90.020

# %%
#fig, ax = plt.subplots(2,1,figsize=(10,10))
#ax[0].set_title('Cross Entropy Loss', fontsize = 20)
#ax[0].plot(history.history['loss'], color='blue', label='Train')
#ax[0].plot(history.history['val_loss'], color='orange', label='Validation')
#ax[0].set_ylabel('Cross Entropy Loss', fontsize = 16)
#ax[0].legend(fontsize = 16)

#ax[1].set_title('Classification Accuracy', fontsize = 20)
#ax[1].plot(history.history['accuracy'], color='blue', label='Train')
#ax[1].plot(history.history['val_accuracy'], color='orange', label='Validation')
#ax[1].set_ylabel('Classification Accuracy', fontsize = 16)
#ax[1].set_xlabel('Epochs', fontsize = 16)
#ax[1].legend(fontsize = 16)

#plt.show()

# %%
#fig.savefig("modelo_"+str(MODELO)+".png")

# %%
model.save('model_10_prime.h5')

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
